# %% [markdown]
# # Trabajo Practico Numero 3 - Raices de Ecuaciones

# %% [markdown]
# * ## `Ejercicio 1`
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definir los datos
x = np.arange(0, 5.1, 0.1) #Incremento en 0.1
y = np.sin(10 * x) + np.cos(3 * x) #Funcion

plt.figure(figsize=(10, 10))
plt.title("Funcion np.sin(10 * x) + np.cos(3 * x)", fontsize=16)
plt.plot(x, y, color='black', label='f(x)', linewidth=2)
plt.axhline(0, color='red', linestyle='--', label='y = 0')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# * ## `Ejercicio 2`
# ![image.png](attachment:image.png)

# %%
import numpy as np

def f1(x: int)->float:
    return np.sin(10 * x) + np.cos(3 * x)

def f2(x: int)->float:
    return x**2+2

print(f"f1(5) = {f1(5)}")
print(f"f1(3) = {f1(3)}")
print(f"f1(10) = {f1(10)}")

print(f"f2(5) = {f2(5)}")
print(f"f2(0) = {f2(0)}")
# Out:
# f1(5) = -1.0220627665627502
# f1(3) = -1.8991618859775388
# f1(10) = -0.35211419122217474
# f2(5) = 27
# f2(0) = 2

# %% [markdown]
# * ## `Ejercicio 3`
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Método Intervalo Medio
# *Aplicado a* \( `f(x) = 24x^3 - 2x^2 - 5x + 1` \)

# %%
import numpy as np
import matplotlib.pyplot as plt
#0.2 0.3 0.3 0.4
# Definir la función a partir de la entrada del usuario
fun = input("Introduzca la función f(x) (use 'x' como variable): ")
f = lambda x: eval(fun)

# Graficar la función
x_vals = np.linspace(-0.6,0.5, 1000)
y_vals = f(x_vals)
plt.figure(figsize=(20,20))
plt.plot(x_vals, y_vals, label='f(x)')
plt.axhline(0, color='red', linestyle='--', label='y = 0')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Gráfica de la función')
plt.grid(True)
plt.legend()
plt.show()

# Obtener los límites
n = int(input('¿Cuántos intervalos desea usar? '))
intervalos = []
for i in range(n):
    a = float(input(f'Introduzca el valor de Lim Inf para el intervalo {i + 1}: '))
    b = float(input(f'Introduzca el valor de Lim Sup para el intervalo {i + 1}: '))
    intervalos.append((a, b))

IntAux = intervalos.copy()
tol = float(input('Introduzca la Tolerancia: '))

for idx, (a, b) in enumerate(IntAux):  # Usar IntAux aquí
    if a > b:
        print(f'Error: El intervalo [{a}, {b}] no es válido. Asegúrese de que Lim Inf < Lim Sup.')
        continue
    
    if f(a) * f(b) >= 0:
        print(f"Error: f(a) y f(b) deben tener signos opuestos para el intervalo [{a}, {b}].")
    else:
        c = (a * f(b) - b * f(a)) / (f(b) - f(a))
        error_aux = 1
        while error_aux > tol:  # Cota de error
            c_ant = c
            if f(c) == 0:
                print(f'La raíz exacta es: {c} en el intervalo [{IntAux[idx]}]')
                break
            elif f(a) * f(c) < 0:
                b = c  # La raíz está en [a, c]
            else:
                a = c  # La raíz está en [c, b]
            c = (a * f(b) - b * f(a)) / (f(b) - f(a))
            error_aux = abs(c - c_ant)
        
        print(f'La raíz aproximada es: {c:.5f} en el intervalo [{IntAux[idx][0]}, {IntAux[idx][1]}]')
# Out:
# La raíz aproximada es: -0.49999 en el intervalo [-0.6, -0.4]
# La raíz aproximada es: 0.25002 en el intervalo [0.2, 0.3]
# La raíz aproximada es: 0.33325 en el intervalo [0.3, 0.4]

# %% [markdown]
# *Aplicado a* \( `f(x) = 0.0018x + 0.3x^2 - 0.0013x^3 - 372` \)

# %%
fun = input("Introduzca la función f(x) (use 'x' como variable): ")
f = lambda x: eval(fun)

# Graficar la función
x_vals = np.linspace(0, 100, 1000)
y_vals = f(x_vals)

plt.plot(x_vals, y_vals, label='f(x)')
plt.axhline(0, color='red', linestyle='--', label='y = 0')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Gráfica de la función')
plt.grid(True)
plt.legend()
plt.show()

# Obtener los límites inferior y superior
a = float(input('Introduzca el valor de Lim Inf: '))
b = float(input('Introduzca el valor de Lim Sup: '))
tol = float(input('Introduzca la Tolerancia: '))

# Método de Intervalo Medio
if f(a) * f(b) >= 0:
    print("Error: f(a) y f(b) deben tener signos opuestos.")
else:
    max_iter = int(np.log((b - a) / tol) / np.log(2))
    for k in range(max_iter):
        c = (a + b) / 2
        if f(a) * f(c) < 0:
            b = c
        elif f(a) * f(c) == 0:
            print(f'La raíz es: {c}')
            break
        else:
            a = c
    else:
        print(f'La raíz aproximada es: {c}')
# Out:
# La raíz aproximada es: 38.58184814453125

# %% [markdown]
# ### Resultados del Método de Intervalo Medio
#
# Después de aplicar el **Método de Intervalo Medio** a la función:
#
# \[
# f(x) = 0.0018x + 0.3x^2 - 0.0013x^3 - 372
# \]
#
# hemos encontrado que la raíz aproximada, que representa la cantidad óptima de impresoras a producir y vender, es:
#
# #### \[ x ≈ 38.58 \]
#
# Esto sugiere que el fabricante debería considerar la producción de aproximadamente **39 impresoras** al mes para maximizar su utilidad.
# <br><br><br>

# %% [markdown]
# * ## `Ejercicio 4`
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Metodo Interpolacion Lineal

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir la función
fun = input("Introduzca la función f(x) (use 'x' como variable): ")
f = lambda x: eval(fun)

# Graficar la función
x_vals = np.linspace(-3, 3, 400)
y_vals = f(x_vals)
plt.ylim(-10,10)
plt.plot(x_vals, y_vals, label='f(x)')
plt.axhline(0, color='red', linestyle='--', label='y = 0')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Gráfica de la función')
plt.grid(True)
plt.legend()
plt.show()

# Obtener los límites
n = int(input('¿Cuántos intervalos desea usar? '))
intervalos = []
for i in range(n):
    a = float(input(f'Introduzca el valor de Lim Inf para el intervalo {i + 1}: '))
    b = float(input(f'Introduzca el valor de Lim Sup para el intervalo {i + 1}: '))
    intervalos.append((a, b))

IntAux = intervalos.copy()

tol = float(input('Introduzca la Tolerancia: '))

for idx, (a, b) in enumerate(IntAux):  # Usar IntAux aquí
    if a > b:
        print(f'Intervalo {a, b} no válido. Ingrese un intervalo válido.')
        continue
    
    if f(a) * f(b) >= 0:
        print(f"Error: f(a) y f(b) deben tener signos opuestos para el intervalo {a, b}.")
    else:
        c = (a * f(b) - b * f(a)) / (f(b) - f(a))
        error_aux = 1
        while error_aux > tol:  # Cota de error
            c_ant = c
            if f(c) == 0:
                print(f'La raíz exacta es: {c} en el intervalo {IntAux[idx]}')
                break
            elif f(a) * f(c) < 0:
                b = c  # La raíz está en [a, c]
            else:
                a = c  # La raíz está en [c, b]
            c = (a * f(b) - b * f(a)) / (f(b) - f(a))
            error_aux = abs(c - c_ant)
        
        print(f'La raíz aproximada es: {c:.5f} en el intervalo [{IntAux[idx][0]}, {IntAux[idx][1]}]')
# Out:
# La raíz aproximada es: -2.19142 en el intervalo [-3.0, -2.0]
# La raíz aproximada es: 0.44344 en el intervalo [0.0, 1.0]
